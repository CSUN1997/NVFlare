# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
with open("/tmp/nvflare/simulate_job/pool_stats/simulator_cell_stats.json", "r") as f:
    results = json.loads(f.read())

# %%
results
# Out:
# {'msg_travel': {'type': 'hist',
#   'pool': {'name': 'msg_travel',
#    'description': 'Time taken (secs) to get here (receiver)',
#    'marks': [0.0001,
#     0.0005,
#     0.001,
#     0.002,
#     0.004,
#     0.008,
#     0.01,
#     0.02,
#     0.04,
#     0.08,
#     0.1,
#     0.2,
#     0.4,
#     0.8,
#     1.0,
#     2.0],
#    'unit': 'second',
#    'cat_data': {'site-1#req:task:register': [{'count': 1,
#       'total': 3.9577484130859375e-05,
#       'min': 3.9577484130859375e-05,
#       'max': 3.9577484130859375e-05},
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      ''],
#     'site-2#req:task:register': [{'count': 1,
#       'total': 1.6689300537109375e-05,
#       'min': 1.6689300537109375e-05,
#       'max': 1.6689300537109375e-05},
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
#      '',
# ...

# %%
ls /tmp/nvflare/simulate_job/
# Out:
# app_server/  app_site-2/  cross_site_val/  meta.json  pool_stats/
# app_site-1/  app_site-3/  log.txt          models/
